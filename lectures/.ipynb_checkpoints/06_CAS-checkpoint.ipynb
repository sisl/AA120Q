# %% [markdown]
# # Building Autonomous Systems

# %% [markdown]
# We will discuss a variety of approaches to building autonomous systems.
#
# Reading: DMU 1.1-1.3

# %% [markdown]
# # Decision Making
#
# Decision making is the process of deciding what to do.
#
# An _agent_ takes _actions_ in an environment. Decision making requires choosing the actions.

# %% [markdown]
# $$\text{action} = act(\> \text{agent}, \text{state}\>)$$

# %% [markdown]
# Oftentimes the agent has to make decisions with incomplete information.

# %% [markdown]
# $$\text{action} = act(\> \text{agent}, \text{state}, \text{belief}\>)$$

# %% [markdown]
# An _intelligent_ agent interacts with the world such that it achieves its objectives over time.
#
# ![Interaction between the environment and the agent.](figures/agent_environment_interaction.png)

# %% [markdown]
# ## Traffic Alert and Collision Avoidance System
#
# TCAS is an onboard collision avoidance system for all medium - large aircraft. The system provides resolution advisories to pilots, instructing them to adjust their climb or descent rate to avoid collision.
#
# ![](figures/pic_tcas_001.jpg)

# %% [markdown]
# TCAS is the final line of defense before a collision. Many safety systems and protocols must fail before it comes into effect.
#
# ![](figures/protected-area.jpg)

# %% [markdown]
# TCAS looks at the approach rate and decides whether to have the airplane pull up or down. A simplified implementation is given in `AA120Q.jl`.

# %%
using AA120Q
agent = TCAS();

# %% [markdown]
# The TCAS agent is a `FullyObservableCollisionAvoidanceSystem`, meaning it assumes perfect state information.
#
# ```
# TCAS <: FullyObservableCollisionAvoidanceSystem
# ```
#
# It thus implements two functions: `reset!` and `update!`

# %%
# reset the TCAS agent to its initial state
function reset!(tcas::TCAS)
    tcas.advisory = ADVISORY_NONE
    tcas
end
# Out:
# reset! (generic function with 1 method)

# %%
# update! contains the real logic
function update!(tcas::TCAS, s1::AircraftState, s2::AircraftState, params::EncounterSimParams)
    # ... collision avoidance logic ... #
    tcas.advisory
end
# Out:
# update! (generic function with 1 method)

# %% [markdown]
# Note that TCAS is completely deterministic.

# %% [markdown]
# The next-gen collision avoidance system, ACAS-X, was developed with stochasticity in mind.
#
# ![](figures/decision_theoretic_planning.png)

# %% [markdown]
# In this class you will build your own collision avoidance system for aircraft.

# %% [markdown]
# # Decision Making Processes

# %% [markdown]
# Computational models of learning have proved largely successful in characterizing potential mechanisms which allow the making of decisions in uncertain and volatile contexts. We can adapt a learning model, depending on separate parameters according to whether we provide a reward or a punishment, can be applied to decision making under uncertainty.
#
# An agent-based decision making model is one of a class of computational models for simulating the actions and interactions of autonomous agents with a view to assessing their effects on the system as a whole. Monte Carlo methods are used to introduce randomness. A central tenet is that the whole is greater than the sum of the parts. Individual agents are typically characterized as boundedly rational, presumed to be acting in what they perceive as their own interests, using heuristics or simple decision-making rules.

# %% [markdown]
# # The Grid World Process

# %% [markdown]
# In the grid world problem we have a $10 \times 10$ grid. Each cell in the grid represents a state in an MDP. The available actions are up, down, left, and right. The effects of these actions are stochastic. We move one step in the specified direction with probability 0.7, and we move one step in one of the three other directions, each with probability 0.1. If we bump against the outer border of the grid, we do not move at all.
#
# We receive a cost of 1 for bumping against the outer border of the grid. There are four cells in which we receive rewards upon entering:
# * $(8,9)$ has a reward of $+10$
# * $(3,8)$ has a reward of $+3$
# * $(5,4)$ has a reward of $-5$
# * $(8,4)$ has a reward of $-10$

# %%
using Interact
include("gridworld.jl")
include("helpers.jl")
g = GridWorld()
plot(g)
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
# 	if (type === "text/latex" && MathJax) {
# 	    MathJax.Hub.Queue(["Typeset", MathJax.Hub, toinsert.get(0)]);
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 //Widgets.log("message received", msg);
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (val[type]) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# TikzPictures.TikzPicture("\\definecolor{currentcolor}{RGB}{255.0,234.6,234.6}\n\\fill[currentcolor] (0.0,9.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 9.0) {\$-0.80\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,8.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 8.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,7.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 7.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,6.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 6.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,5.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 5.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,4.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 4.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,3.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 3.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,2.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 2.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,237.15,237.15}\n\\fill[currentcolor] (0.0,1.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 1.0) {\$-0.70\$};\n\\definecolor{currentcolor}{RGB}{255.0,234.6,234.6}\n\\fill[currentcolor] (0.0,0.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 0.0) {\$-0.80\$};\n\\definecolor{currentcolor}{RGB}{255.0,252.45,252.45}\n\\fill[currentcolor] (1.0,9.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 9.0) {\$-0.10\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,8.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 8.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,7.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 7.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,6.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 6.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,5.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 5.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,4.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 4.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,3.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 3.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,2.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 2.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,1.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 1.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,252.45,252.45}\n\\fill[currentcolor] (1.0,0.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 0.0) {\$-0.10\$};\n\\definecolor{currentcolor}{RGB}{255.0,252.45,252.45}\n\\fill[currentcolor] (2.0,9.0) rectangle +(1.0,1.0);\n\\node[above right] at (2.0, 9.0) {\$-0.10\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (2.0,8.0) rectangle +(1.0,1.0);\n\\node[above right] at (2.0, 8.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (2.0,7.0) rectangle +(1.0,1.0);\n\\node[above right] at (2.0, 7.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (2.0,6.0) rectangle +(1.0,1.0);\n\\node[above right] at (2.0, 6.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (2.0,5.0) rectangle +(1.0,1.0);\n\\node[above right] at (2.0, 5.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (2.0,4.0) recta ...

# %% [markdown]
# The coordinates are specified using the matrix convention in which the first coordinate is the row starting from the top and the second coordinate is the column starting from the left. The cells with rewards of $+10$ and $+3$ are absorbing states where no additional reward is ever received from that point onward.

# %% [markdown]
# ## Policy Evaluation
#
# You can estimate the value of a state by successively propagating the reward from other states.

# %%
function iterativePolicyEvaluation(mdp::MDP, policy::Function, numIterations::Integer)
    (S, A, T, R, discount) = locals(mdp)
    U = @array (s0 in S) 0.
    for t = 1:numIterations
        U = @array (s0 in S) begin
            R(s0, policy(s0)) + discount*@sum (s1 in S) (T(s0, policy(s0), s1)*U[s1])
            end
    end
    U
end;

# %%
@manipulate for numIterations = 0:10, a = actions(g), discount = 0.1:0.1:0.9
    policy = s -> a
    g.discount = discount
    U = iterativePolicyEvaluation(g, policy, numIterations)
    plot(g, U, policy)
end
# Out:
# Interact.Slider{Int64}(Signal{Int64}(5, nactions=0),"numIterations",5,0:10,"d",true)
# Interact.Options{:ToggleButtons,Symbol}(Signal{Symbol}(left, nactions=0),"a",:left,"left",Interact.OptionDict(Any["left","right","up","down"],Dict{Any,Any}("left"=>:left,"right"=>:right,"down"=>:down,"up"=>:up)),Any[],Any[])
# Interact.Slider{Float64}(Signal{Float64}(0.5, nactions=0),"discount",0.5,0.1:0.1:0.9,".3f",true)
# TikzPictures.TikzPicture("\\definecolor{currentcolor}{RGB}{255.0,217.714951875,217.714951875}\n\\fill[currentcolor] (0.0,9.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,221.94160875,221.94160875}\n\\fill[currentcolor] (0.0,8.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.26660625,222.26660625}\n\\fill[currentcolor] (0.0,7.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.2836115625,222.2836115625}\n\\fill[currentcolor] (0.0,6.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.2661121875,222.2661121875}\n\\fill[currentcolor] (0.0,5.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.2844403125,222.2844403125}\n\\fill[currentcolor] (0.0,4.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.2804240625,222.2804240625}\n\\fill[currentcolor] (0.0,3.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,222.223575,222.223575}\n\\fill[currentcolor] (0.0,2.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,221.93523375,221.93523375}\n\\fill[currentcolor] (0.0,1.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,217.714951875,217.714951875}\n\\fill[currentcolor] (0.0,0.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,237.98385000000002,237.98385000000002}\n\\fill[currentcolor] (1.0,9.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.210506875,242.210506875}\n\\fill[currentcolor] (1.0,8.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.530723125,242.530723125}\n\\fill[currentcolor] (1.0,7.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.5078846875,242.5078846875}\n\\fill[currentcolor] (1.0,6.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.2059009375,242.2059009375}\n\\fill[currentcolor] (1.0,5.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.4991509375,242.4991509375}\n\\fill[currentcolor] (1.0,4.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.4552909375,242.4552909375}\n\\fill[currentcolor] (1.0,3.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,241.834254375,241.834254375}\n\\fill[currentcolor] (1.0,2.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,242.114881875,242.114881875}\n\\fill[currentcolor] (1.0,1.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,237.9742875,237.9742875}\n\\fill[currentcolor] (1.0,0.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,245.9993925,245.9993925}\n\\fill[currentcolor] (2.0,9.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,250.222861875,250.222861875}\n\\fill[currentcolor] (2.0,8.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,250.503234375,250.503234375}\n\\fill[currentcolor] (2.0,7.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,249.8572396875,249.8572396875}\n\\fill[currentcolor] (2.0,6.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,243.7603809375,243.7603809375}\n\\fill[currentcolor] (2.0,5.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,249.7624434375,249.7624434375}\n\\fill[currentcolor] (2.0,4.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,249.0954271875,249.0954271875}\n\\fill[currentcolor] (2.0,3.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,236.937234375,236.937234375}\n\\fill[currentcolor] (2.0,2.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,248.798049375,248.798049375}\n\\fill[currentcolor] (2.0,1.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,245.8973925,245.8973925}\n\\fill[currentcolor] (2.0,0.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,249.0872034375,249.0872034375}\n\\fill[currentcolor] (3.0,9.0) rectangle +(1.0,1.0);\n\\definecolor{currentcolor}{RGB}{255.0,253.2987196875,253.2987196875}\n\\fill[currentcolor] (3.0,8.0) rectangle +(1.0,1.0);\n\\definecolor{currentcol ...

# %% [markdown]
# ## Policy Evaluation in Continuous Spaces
#
# For continuous spaces you often cannot use discrete solving methods.
# Instead, if you have a policy $\pi(s) \rightarrow a$ and a distribution over the initial state, you can evaluate it by running a lot of simulations and returning the mean reward.

# %% [markdown]
# ### Moutain Car
#
# An [under-powered car must drive up a steep hill](https://en.wikipedia.org/wiki/Mountain_Car). Simply holding the throttle isn't good enough.
#
# __State__: position $x$ and velocity $v$

# %%
type MountainCar
    x::Float64 # position
    v::Float64 # speed
end

# %%
include("mountaincar.jl")
@manipulate for x in -1.5:0.1:1.5, y in -1.0:0.25:1.0
    render_mountain_car(MountainCar(x,y), render_pos_overlay=true)
end
# Out:
# Interact.Slider{Float64}(Signal{Float64}(0.0, nactions=0),"x",0.0,-1.5:0.1:1.5,".3f",true)
# Interact.Slider{Float64}(Signal{Float64}(0.0, nactions=0),"y",0.0,-1.0:0.25:1.0,".3f",true)
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000002daea00,1000.0,600.0,#undef)

# %% [markdown]
# __Actions__: accelerate left, right or coast

# %%
function update!(car::MountainCar, a::Symbol)
    act = (a == :left ? -1 : (a == :right ? 1 : 0))
    v2 = car.v + act*0.001 - sin((car.x/1.5 + 1)*pi)*-0.0025
    x2 = clamp(car.x + v2, -1.5, 1.5)
    MountainCar(x2, v2)
end
# Out:
# update! (generic function with 2 methods)

# %% [markdown]
# __Reward__: $R(s,a) = y$

# %%
reward(car::MountainCar, a::Symbol) = -cos(car.x/1.5*pi)
# Out:
# reward (generic function with 1 method)

# %% [markdown]
# ### Policy: Floor It

# %%
car = MountainCar(0.0,0.0)
R = 0.0
function tick!(t, Δt=1/60)
    global car
    a = :right
    car = update!(car, a)
    global R = R*0.99 + reward(car, a)
    render_mountain_car(car, render_pos_overlay=true, reward=R)
end
map(tick!, map(_ -> time(), fps(60)))
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00000000074c2450,1000.0,600.0,#undef)

# %% [markdown]
# ### Policy: boost in direction of your velocity

# %%
car2 = MountainCar(0.0,0.0)
R2 = 0.0
function tick2!(t, Δt=1/60)
    
    global car2
    a = car2.v > 0.0 ? :right : :left
    car2 = update!(car2, a)
    global R2 = R2*0.99 + reward(car2, a)
    render_mountain_car(car2, render_pos_overlay=true, reward=R2)
end
map(tick2!, map(_ -> time(), fps(60)))
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000006fef7d0,1000.0,600.0,#undef)

# %% [markdown]
# # Assignment 6

# %% [markdown]
# In this assignment, you are expected to write your own collision avoidance system (CAS).
# You are given a lot of freedom in order to accomplish this task. The implementation you see below is merely _one_ way in which this can be done.
#
# Your objective is to find a CAS policy $\pi(s) \rightarrow a$ which minimizes collisions and alerts. We want a safe system (few collisions) but we also do not want to alert when we do not need to (few alerts).
#
# Collision avoidance systems will be judged according to a _cost function_ $J(\text{encounter}) \rightarrow \mathbb{R}$.
# We want to minimize the expected penalty accumulated by the CAS.
# Formally:
#
# $$\min_\pi \mathbb{E}\left[J_\pi(\text{encounter})\right]$$
#
# What this means is that we want the policy $\pi$ which on average produces encounters with minimum penalites.
# We can estimate the performance of a policy by running a large number of encounters with it and then taking the mean of the accumulated penalty.

# %% [markdown]
# Penalties in this assignment are computed according to:
#
# * a penalty of 10 for issuing an advisory - only issue advisories when you need to
# * a penality equal to the magnitude of the advised climb rate each time a new advisory is issued - weak climb rates are easier on the passengers
# * a penalty of 50 for a reversal - a change of sign in the advisory
# * a penalty of 1e5 for an near mid-air collision (NMAC) - being within 100 ft vertically or 500 ft horizontally of another plane

# %% [markdown]
# ### What is Turned In
#
# Write all of your code in a file structured identically to "my_cas.jl" and turn it in to Coursework.

# %%
using AA120Q
# Out:
# INFO: Precompiling module AA120Q...

# %% [markdown]
# Here is a dataset of fully-human encounters, which you can then use to collect your own set of encounters to evaluate your Collision Avoidance System (CAS).

# %%
initial, traces = get_dataset("small")
encounters = pull_encounters(initial, traces, 500);
# Out:
# LoadError: UndefVarError: readtable not defined
# while loading In[1], in expression starting on line 1

# %%
plot_encounter(encounters[1])   # Sample Plot
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# Here we're simulating trajectories using the [provided] traffic and collision avoidance system (TCAS). You will then design your own CAS (see below), and then compare the two results, to see if your model gets similar results as the standard model.

# %%
srand(0)
enc = rand(encounters[1], TCAS())
plot_encounter(enc)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## Demonstrative Collision Avoidance System - (DCAS)
#
# Here is a demonstrative collision avoidance system, which is a fully-functional out-of-the-box CAS. It will leverage the model and the AA120Q API. The two functions reset() and update() are implemented here. Use it as a starting point to design your own CAS.
#
# The model will issue an Advisory (or none) at each timestep. Issuing ADVISORY_NONE or your previous advisory is equivalent to issuing no advisory.

# %%
type DemoCAS <: FullyObservableCollisionAvoidanceSystem
    range_threshold::Float64
    last_advisory::Advisory
    DemoCAS(range_threshold::Float64, last_advisory::Advisory=ADVISORY_NONE) = new(range_threshold, last_advisory)
end

# %% [markdown]
# A reset function to start it anew

# %%
function AA120Q.reset!(dcas::DemoCAS)
    dcas.last_advisory = ADVISORY_NONE
    dcas
end
# Out:
# reset! (generic function with 3 methods)

# %% [markdown]
# The update function issues an advisory

# %%
function AA120Q.update!(dcas::DemoCAS, s1::AircraftState, s2::AircraftState, params::EncounterSimParams)

    # pull TCAS observations
    x1, y1, h1 = s1.e, s1.n, s1.h
    x2, y2, h2 = s2.e, s2.n, s2.h

    range = norm([(x2 - x1), (y2 - y1)]) # range [ft]
    relalt = abs(h1 - h2) # relative altitude [ft]

    # test for activation
    if is_no_advisory(dcas.last_advisory) && range < dcas.range_threshold
        dcas.last_advisory = Advisory(CLIMB_RATE_MAX) # climb!
    end
        
    dcas.last_advisory
end
# Out:
# update! (generic function with 5 methods)

# %% [markdown]
# You can now simulate trajectories with your custom CAS...

# %%
srand(0)
enc = rand(encounters[1], DemoCAS(1000.0))
plot_encounter(enc)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # Pull Evaluation Metrics

# %% [markdown]
# Use `evaluate` to report the number of advisories and near midair collisions (NMACs). Remember that a good safety system will minimize both the number of collisions and the number of alerts. We will measure performance based on the average cost per trajectory, `CASEval.normalized`. Try to minimize it!

# %%
# run every encounter once
evaluate(DemoCAS(1000.0), encounters)
# Out:
# CASEval(n_encounters: 3, n_advisories: 3, n_NMACs: 0, penalty: 400.00, normalized: 133.33)

# %%
# randomly sample 50 encounters from `encounters`
evaluate(DemoCAS(1000.0), encounters, 50)
# Out:
# CASEval(n_encounters: 50, n_advisories: 50, n_NMACs: 0, penalty: 6666.67, normalized: 133.33)
